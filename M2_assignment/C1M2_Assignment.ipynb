# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are a researcher.
    
    Generate an initial draft of an essay on a {topic}
    """ 

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are a essay reviewer.
    
    Review essay {draft} and provide constructive feedback.
    
    Requirements:
    The feedback should be critical but constructive.
    It should address issues such as structure, clarity, strength of argument, and writing style.
    
    Return a string with feedback in paragraph form.
    """ 

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are a researcher who is revising the draft essay based on the feedback.
    
    Improve a given essay {original_draft} based on feedback text {reflection}
    
    Requirements:
    The revised draft should address the issues mentioned in the feedback.
    It should improve clarity, coherence, argument strength, and overall flow.
    The function should use the feedback to guide the revision, and return only the final revised essay.
    
    Return a string containing the revised and improved essay.
    """ 

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: Navigating the Digital Frontier: The Case for Government Regulation of Social Media Platforms
#
# Introduction:
#
# In the contemporary digital age, social media platforms have revolutionized the way we communicate, access information, and perceive the world. They have become integral to our personal lives, work, and political discourse, shaping public opinion and even influencing the democratic processes. However, with great power comes great responsibility, and it has become increasingly clear that the unregulated landscape of social media presents significant challenges. Consequently, a pertinent question arises: should social media platforms be regulated by the government? This essay delves into the various dimensions of this debate, exploring the potential benefits and drawbacks of governmental regulation of social media.
#
# The Case for Regulation:
#
# 1. **Protecting Democratic Processes:** The influence of social media on political elections has been a topic of concern in recent years. Instances of foreign interference, the spread of misinformation, and targeted fake news campaigns have undermined the integrity of democratic processes. Government regulation could establish clear standards to mitigate these risks, ensuring that elections remain fair and impartial.
#
# 2. **Safeguarding Privacy:** Social media platforms collect vast amounts of personal data, often without users' informed consent. Regulation could enforce stricter data privacy laws, empowering users and giving them control over their personal information. Frameworks similar to the General Data Protection Regulation (GDPR) in Europe could serve as models to ensure transparency and accountability in data handling practices.
#
# 3. **Combating Hate Speech and Online Harassment:** The anonymity offered by social media can sometimes lead to an increase in hate speech and online harassment. Government regulation could mandate platforms to adopt more efficient monitoring systems and establish clearer content moderation guidelines, fostering a safer online environment for all users.
#
# 4. **Ensuring Market Competition:** The dominance of a few major social media companies has stifled competition and innovation in the sector. Regulation could address these monopolistic tendencies, encouraging entry of new players and promoting a more dynamic digital economy.
#
# The Case Against Regulation:
#
# 1. **Freedom of Expression Concerns:** One of the core arguments against governmental regulation is the potential infringement on free speech. Critics argue that regulation might lead to censorship and the suppression of diverse viewpoints, contravening the fundamental democratic principle of freedom of expression.
#
# 2. **Innovation Impediments:** Excessive regulation could stifle innovation by creating barriers to entry for new platforms and overwhelming smaller companies with compliance costs. The rapid evolution of technology demands flexibility and adaptability, which heavy-handed regulation might hinder.
#
# 3. **Global Jurisdiction Complications:** Social media platforms operate on a global scale, making it challenging for any single government to regulate them effectively. Different countries have varying legal standards, leading to potential conflicts and complications in creating a cohesive regulatory framework.
#
# 4. **Responsibility and Accountability:** Some argue that social media companies should be held responsible for self-regulation. By taking proactive steps to address the negative impacts of their platforms, these companies can demonstrate corporate responsibility without governmental intervention.
#
# Conclusion:
#
# The question of whether social media platforms should be regulated by the government is complex and multifaceted. While there are compelling arguments for regulation, particularly in protecting democratic processes, privacy, and combating hate speech, there are also valid concerns regarding free expression and innovation. Ultimately, a balanced approach is needed—one that fosters accountability and responsibility, both from social media companies and governments, without stifling the dynamic and transformative nature of the digital age. In this evolving landscape, ongoing dialogue and collaboration among stakeholders will be crucial in crafting effective and nuanced regulatory frameworks that protect individual rights while promoting a healthy online ecosystem.
#
# 🧠 Feedback:
#
# The essay presents a clear and timely discussion of government regulation of social media, and your organizational scheme—laying out the case for and against regulation before concluding—provides a logical roadmap for the reader. To sharpen the structure, however, you might consider opening with an explicit thesis statement that previews your ultimate position or the balanced approach you favor, rather than allowing the reader to infer your stance only in the conclusion. In each of your body paragraphs, the headings help to clarify your points, but the argument would gain force if you integrated concrete examples—such as specific instances of election interference, case studies of GDPR enforcement, or real legal challenges faced by platforms—to lend empirical weight. Transitions between sections could also be smoother; for instance, after discussing privacy, you might briefly acknowledge how privacy concerns intersect with free‐speech arguments before moving on to hate speech, which would reinforce the interconnectedness of these issues.
#
# On clarity and style, your prose is generally precise and formal, but it occasionally slips into broad generalizations (e.g., “vast amounts of personal data” or “significant challenges”) without quantification; adding statistics or citing studies would make your assertions more authoritative. When you address counterarguments, strive to engage more deeply—describe potential regulatory frameworks that opponents fear might chill speech, and then directly explain how those fears could be alleviated by well-designed safeguards. Finally, the conclusion aptly calls for collaboration but could be more powerful by summarizing the key criteria for an effective regulatory model (for example, proportionality, transparency, and respect for fundamental rights) and suggesting next steps for policymakers, platforms, and civil society. By tightening your thesis, enriching your discussion with examples, and refining your transitions, you will elevate both the persuasiveness and readability of your essay.
#
# ✍️ Revised:
#
# Title: Navigating the Digital Frontier: The Case for Government Regulation of Social Media Platforms
#
# Introduction:
#
# In the contemporary digital age, social media platforms have become an unparalleled force, revolutionizing communication, information access, and worldly perceptions. As vital components of personal life, professional realms, and political discourse, these platforms have significantly influenced public opinion and democratic processes. However, their considerable power necessitates corresponding responsibility. Consequently, the question arises: should social media platforms be regulated by the government? This essay argues for a balanced approach to regulation—one that ensures accountability and safeguards public interests without stifling innovation and freedom of expression. Exploring both sides of the debate, the essay examines the potential benefits and drawbacks of governmental regulation of social media, with an emphasis on empirical examples and a discussion of viable regulatory frameworks.
#
# The Case for Regulation:
#
# 1. **Protecting Democratic Processes:** Social media's influence on political elections has recently prompted serious concerns. Notable instances include the 2016 U.S. presidential elections and the Brexit referendum, where foreign interference and misinformation campaigns were rampant. Government regulation could establish clear standards to curb these threats, ensuring elections remain fair and impartial. A model approach could emulate the UK's Online Safety Bill, which mandates transparency reports from platforms regarding disinformation actions.
#
# 2. **Safeguarding Privacy:** Social media platforms collect extensive personal data, often without explicit user consent. The Cambridge Analytica scandal highlighted the consequences of unregulated data misuse. Regulation, akin to Europe's General Data Protection Regulation (GDPR), could ensure data handling transparency and user empowerment, compelling platforms to secure user information comprehensively and accountably.
#
# 3. **Combating Hate Speech and Online Harassment:** The anonymity afforded by social media can foster hostility, leading to rampant hate speech and online harassment. Regulatory mandates could require platforms to adopt sophisticated monitoring systems and definitive content moderation guidelines. Germany's NetzDG law, which compels swift removal of illegal content, exemplifies such a measure, fostering a safer digital environment.
#
# 4. **Ensuring Market Competition:** Major social media corporations exercise immense market dominance, stifling competition and innovation. Regulatory frameworks could address these monopolistic trends, as seen in the European Union’s antitrust actions against major tech giants, encouraging newcomer entry and a more vibrant digital economy.
#
# The Case Against Regulation:
#
# 1. **Freedom of Expression Concerns:** One core argument against governmental regulation is potential free speech infringement. Critics worry prospective regulatory frameworks might resemble the Chinese model, which heavily censors diverse viewpoints. However, well-designed safeguards, emphasizing proportionality and transparency, can alleviate these fears, protecting fundamental democratic principles.
#
# 2. **Innovation Impediments:** Excessive regulation could hinder innovation, burdening new platforms with compliance costs. Consider the stringent requirements under the Digital Services Act, which some argue could disadvantage smaller entities. A nuanced approach, focusing on flexibility and adaptability, could prevent the stifling of technological evolution.
#
# 3. **Global Jurisdiction Complications:** The transnational nature of social media complicates unilateral regulation. The varied legal landscapes across jurisdictions complicate cohesive framework creation, as exemplified by the challenges faced by the GDPR's extraterritorial applicability. International collaboration, fostering consistent standards, could address these complications effectively.
#
# 4. **Responsibility and Accountability:** Advocates of self-regulation argue that social media companies should address platform impacts proactively. Instances like Twitter's stance against political advertising demonstrate corporate responsibility. Emphasizing self-regulation encourages companies to innovate in moderation techniques without governmental intervention.
#
# Conclusion:
#
# The question of governmental regulation of social media platforms is inherently complex and multifaceted. A balanced approach—recognizing both compelling arguments for regulation in defending democratic processes, privacy, and combating hate speech, and concerns for preserving freedom of expression and fostering innovation—is essential. Collaboration among policymakers, platforms, and civil society will be crucial in designing effective, proportional, and transparent regulatory frameworks that respect fundamental rights. By doing so, stakeholders can create a healthy online ecosystem that holds platforms accountable and nurtures the dynamic, transformative potential of the digital age. Future steps should focus on encouraging dialogue, reinforcing international cooperation, and developing adaptive regulatory models responsive to evolving digital landscapes.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Navigating the Digital Frontier: The Case for Government Regulation of Social Media Platforms
#
# Introduction:
#
# In the contemporary digital age, social media platforms have revolutionized the way we communicate, access information, and perceive the world. They have become integral to our personal lives, work, and political discourse, shaping public opinion and even influencing the democratic processes. However, with great power comes great responsibility, and it has become increasingly clear that the unregulated landscape of social media presents significant challenges. Consequently, a pertinent question arises: should social media platforms be regulated by the government? This essay delves into the various dimensions of this debate, exploring the potential benefits and drawbacks of governmental regulation of social media.
#
# The Case for Regulation:
#
# 1. **Protecting Democratic Processes:** The influence of social media on political elections has been a topic of concern in recent years. Instances of foreign interference, the spread of misinformation, and targeted fake news campaigns have undermined the integrity of democratic processes. Government regulation could establish clear standards to mitigate these risks, ensuring that elections remain fair and impartial.
#
# 2. **Safeguarding Privacy:** Social media platforms collect vast amounts of personal data, often without users' informed consent. Regulation could enforce stricter data privacy laws, empowering users and giving them control over their personal information. Frameworks similar to the General Data Protection Regulation (GDPR) in Europe could serve as models to ensure transparency and accountability in data handling practices.
#
# 3. **Combating Hate Speech and Online Harassment:** The anonymity offered by social media can sometimes lead to an increase in hate speech and online harassment. Government regulation could mandate platforms to adopt more efficient monitoring systems and establish clearer content moderation guidelines, fostering a safer online environment for all users.
#
# 4. **Ensuring Market Competition:** The dominance of a few major social media companies has stifled competition and innovation in the sector. Regulation could address these monopolistic tendencies, encouraging entry of new players and promoting a more dynamic digital economy.
#
# The Case Against Regulation:
#
# 1. **Freedom of Expression Concerns:** One of the core arguments against governmental regulation is the potential infringement on free speech. Critics argue that regulation might lead to censorship and the suppression of diverse viewpoints, contravening the fundamental democratic principle of freedom of expression.
#
# 2. **Innovation Impediments:** Excessive regulation could stifle innovation by creating barriers to entry for new platforms and overwhelming smaller companies with compliance costs. The rapid evolution of technology demands flexibility and adaptability, which heavy-handed regulation might hinder.
#
# 3. **Global Jurisdiction Complications:** Social media platforms operate on a global scale, making it challenging for any single government to regulate them effectively. Different countries have varying legal standards, leading to potential conflicts and complications in creating a cohesive regulatory framework.
#
# 4. **Responsibility and Accountability:** Some argue that social media companies should be held responsible for self-regulation. By taking proactive steps to address the negative impacts of their platforms, these companies can demonstrate corporate responsibility without governmental intervention.
#
# Conclusion:
#
# The question of whether social media platforms should be regulated by the government is complex and multifaceted. While there are compelling arguments for regulation, particularly in protecting democratic processes, privacy, and combating hate speech, there are also valid concerns regarding free expression and innovation. Ultimately, a balanced approach is needed—one that fosters accountability and responsibility, both from social media companies and governments, without stifling the dynamic and transformative nature of the digital age. In this evolving landscape, ongoing dialogue and collaboration among stakeholders will be crucial in crafting effective and nuanced regulatory frameworks that protect individual rights while promoting a healthy online ecosystem.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">The essay presents a clear and timely discussion of government regulation of social media, and your organizational scheme—laying out the case for and against regulation before concluding—provides a logical roadmap for the reader. To sharpen the structure, however, you might consider opening with an explicit thesis statement that previews your ultimate position or the balanced approach you favor, rather than allowing the reader to infer your stance only in the conclusion. In each of your body paragraphs, the headings help to clarify your points, but the argument would gain force if you integrated concrete examples—such as specific instances of election interference, case studies of GDPR enforcement, or real legal challenges faced by platforms—to lend empirical weight. Transitions between sections could also be smoother; for instance, after discussing privacy, you might briefly acknowledge how privacy concerns intersect with free‐speech arguments before moving on to hate speech, which would reinforce the interconnectedness of these issues.
#
# On clarity and style, your prose is generally precise and formal, but it occasionally slips into broad generalizations (e.g., “vast amounts of personal data” or “significant challenges”) without quantification; adding statistics or citing studies would make your assertions more authoritative. When you address counterarguments, strive to engage more deeply—describe potential regulatory frameworks that opponents fear might chill speech, and then directly explain how those fears could be alleviated by well-designed safeguards. Finally, the conclusion aptly calls for collaboration but could be more powerful by summarizing the key criteria for an effective regulatory model (for example, proportionality, transparency, and respect for fundamental rights) and suggesting next steps for policymakers, platforms, and civil society. By tightening your thesis, enriching your discussion with examples, and refining your transitions, you will elevate both the persuasiveness and readability of your essay.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Navigating the Digital Frontier: The Case for Government Regulation of Social Media Platforms
#
# Introduction:
#
# In the contemporary digital age, social media platforms have become an unparalleled force, revolutionizing communication, information access, and worldly perceptions. As vital components of personal life, professional realms, and political discourse, these platforms have significantly influenced public opinion and democratic processes. However, their considerable power necessitates corresponding responsibility. Consequently, the question arises: should social media platforms be regulated by the government? This essay argues for a balanced approach to regulation—one that ensures accountability and safeguards public interests without stifling innovation and freedom of expression. Exploring both sides of the debate, the essay examines the potential benefits and drawbacks of governmental regulation of social media, with an emphasis on empirical examples and a discussion of viable regulatory frameworks.
#
# The Case for Regulation:
#
# 1. **Protecting Democratic Processes:** Social media's influence on political elections has recently prompted serious concerns. Notable instances include the 2016 U.S. presidential elections and the Brexit referendum, where foreign interference and misinformation campaigns were rampant. Government regulation could establish clear standards to curb these threats, ensuring elections remain fair and impartial. A model approach could emulate the UK's Online Safety Bill, which mandates transparency reports from platforms regarding disinformation actions.
#
# 2. **Safeguarding Privacy:** Social media platforms collect extensive personal data, often without explicit user consent. The Cambridge Analytica scandal highlighted the consequences of unregulated data misuse. Regulation, akin to Europe's General Data Protection Regulation (GDPR), could ensure data handling transparency and user empowerment, compelling platforms to secure user information comprehensively and accountably.
#
# 3. **Combating Hate Speech and Online Harassment:** The anonymity afforded by social media can foster hostility, leading to rampant hate speech and online harassment. Regulatory mandates could require platforms to adopt sophisticated monitoring systems and definitive content moderation guidelines. Germany's NetzDG law, which compels swift removal of illegal content, exemplifies such a measure, fostering a safer digital environment.
#
# 4. **Ensuring Market Competition:** Major social media corporations exercise immense market dominance, stifling competition and innovation. Regulatory frameworks could address these monopolistic trends, as seen in the European Union’s antitrust actions against major tech giants, encouraging newcomer entry and a more vibrant digital economy.
#
# The Case Against Regulation:
#
# 1. **Freedom of Expression Concerns:** One core argument against governmental regulation is potential free speech infringement. Critics worry prospective regulatory frameworks might resemble the Chinese model, which heavily censors diverse viewpoints. However, well-designed safeguards, emphasizing proportionality and transparency, can alleviate these fears, protecting fundamental democratic principles.
#
# 2. **Innovation Impediments:** Excessive regulation could hinder innovation, burdening new platforms with compliance costs. Consider the stringent requirements under the Digital Services Act, which some argue could disadvantage smaller entities. A nuanced approach, focusing on flexibility and adaptability, could prevent the stifling of technological evolution.
#
# 3. **Global Jurisdiction Complications:** The transnational nature of social media complicates unilateral regulation. The varied legal landscapes across jurisdictions complicate cohesive framework creation, as exemplified by the challenges faced by the GDPR's extraterritorial applicability. International collaboration, fostering consistent standards, could address these complications effectively.
#
# 4. **Responsibility and Accountability:** Advocates of self-regulation argue that social media companies should address platform impacts proactively. Instances like Twitter's stance against political advertising demonstrate corporate responsibility. Emphasizing self-regulation encourages companies to innovate in moderation techniques without governmental intervention.
#
# Conclusion:
#
# The question of governmental regulation of social media platforms is inherently complex and multifaceted. A balanced approach—recognizing both compelling arguments for regulation in defending democratic processes, privacy, and combating hate speech, and concerns for preserving freedom of expression and fostering innovation—is essential. Collaboration among policymakers, platforms, and civil society will be crucial in designing effective, proportional, and transparent regulatory frameworks that respect fundamental rights. By doing so, stakeholders can create a healthy online ecosystem that holds platforms accountable and nurtures the dynamic, transformative potential of the digital age. Future steps should focus on encouraging dialogue, reinforcing international cooperation, and developing adaptive regulatory models responsive to evolving digital landscapes.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
